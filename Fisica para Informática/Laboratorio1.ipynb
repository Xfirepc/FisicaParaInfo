# %% [markdown]
# # El efecto fotoeléctrico
#
# ## Breve concepto de la prática
# Cuando la luz brilla en un metal, los electrones pueden ser expulsados de la superficie del metal en un fenómeno conocido como el efecto fotoeléctrico. También, a este proceso suele llamársele fotoemisión, y a los electrones que son expulsados del metal, fotoelectrones. En términos de su comportamiento y sus propiedades, los fotoelectrones no son diferentes de otros electrones. El prefijo foto simplemente nos indica que los electrones han sido expulsados de la superficie de un metal por la luz incidente.
#
# ![Ejemplo grafico](images/main.png "Efecto fotoeléctrico")
#
# ## Objetivo
# - Realizar de manera computacional dos ejercicios que recrean dos experimentos sobre física moderna: el movimiento de partículas cargadas en campos magnéticos y el efecto fotoeléctrico
#
# ## Integrantes
# - José Flores Arias
#
#
# ## Desarrollo de la actividad
#
#
# ### Por hacer con latex Comprueba que e⋅V tiene unidades de energía, donde e es la carga del electrón.
# Einstein postuló que el efecto fotoeléctrico podía asimilarse a un uno-contra-uno de partículas de luz (llamadas fotones) con cada electrón. La energía de estos fotones sería E=hf, donde f es la frecuencia de la luz (y por ende, de cada fotón) y h es la así llamada constante de Planck, arriba nombrada. De esta manera, podemos reescribir la ecuación anterior como: eV=hf-ϕ.
#
# ### Por hacer con latex Esta última expresión también se puede representar como y=m⋅x+b, donde:
#
# m=(y_1-y_2)/(x_1-x_2 ),    b=(x_1⋅y_2-x_2⋅y_1)/(x_1-x_2 )  "(3)."
#
# Ejercicio de calentamiento: demuestra la equivalencia de la relación matemática anterior, es decir, que:
#
# (x-x_1)/(x_2-x_1 )=(y-y_1)/(y_2-y_1 ) "es equivalente a " y=m⋅x+b  "(4)."
#
# Pista: solo tenéis que despejar y y buscar los sumandos que multipliquen a x y los que no (concepto de factor común que se nos enseñaba en el colegio). Se trata de un ejercicio muy sencillo de matemáticas (muy) básicas. Desarrollad este ejercicio en una celda Markdown y con pasos en los que las matemáticas estén escritas en LaTeX.

# %% [markdown]
# ## Relacion entre frecuencia y longitud de onda
#
# Para obtener la frecuencia de una honda es necesario conocer su velocidad de propagacion que para este caso es; la velocidad de la luz constante y su longitud de onda. Teniendo la relacion de:
# $$ v = 300.000.000  \frac{m}{s} $$
# $$ f = \frac{v}{\lambda} $$
#
# ## Tabla de datos
#
#
# | Color        | Longitud de onda (m)    | Frecuencia (Hz) | Voltaje (V) | Gráfico |
# |--------------|-------------------------|-----------------|-------------|---------|
# | Verde        | $$ 5 \cdot 10^{-7} $$   |        6        | -0.20       | x       |
# | Azul         | $$ 4.5 \cdot 10^{-7} $$ |      6.6667     | -0.50       | x       |
# | Violeta      | $$ 4 \cdot 10^{-7} $$   |       7.5       | -0.80       | x       |
# | Ultravioleta | $$ 3 \cdot 10^{-7} $$   |        10       | -1.80       | x       |
# | Ultravioleta | $$ 2.5 \cdot 10^{-7} $$ |        12       | -2.70       | x       |

# %% [markdown]
# ## Grafico de los datos
# Para graficar los datos (longitud de onda vs voltaje) utilizamos el paquete de mathplotlib de python.

# %%
import matplotlib.pyplot as plt 

# Defino los valores de longitud de onda en longitud_onda y
# los valores para los voltajes en diff_potential en vectores
longitud_onda = [500, 450, 400, 300, 250]
diff_potential = [-0.2, -0.5, -0.8, -1.8, -2.70]

# Preparamos y mostramos el grafico en pyplot con los datos anteriores
plt.xlabel("Longitud de onda [nm]") 
plt.ylabel("Voltaje [V]") 
plt.plot(longitud_onda, diff_potential, 'p')
plt.show()
